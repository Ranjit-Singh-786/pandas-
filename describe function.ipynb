# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('pollice data.csv')
data.head(3)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
# 2        33.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False
# 2         NaN     Citation       False      0-15 Min               False

# %%
data.describe()       #for all numeric column
# this is not calculate a catogorical column
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %%
data.describe(include= 'all')
# for all columns describe numeric and categorical
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# count       65535     65535           0.0         61474    61481.000000
# unique       2651      1432           NaN             2             NaN
# top     1/11/2012     11:00           NaN             M             NaN
# freq           69       280           NaN         45164             NaN
# mean          NaN       NaN           NaN           NaN     1967.791106
# std           NaN       NaN           NaN           NaN      121.050106
# min           NaN       NaN           NaN           NaN        0.000000
# 25%           NaN       NaN           NaN           NaN     1965.000000
# 50%           NaN       NaN           NaN           NaN     1978.000000
# 75%           NaN       NaN           NaN           NaN     1985.000000
# max           NaN       NaN           NaN           NaN     8801.000000
#
#           driver_age driver_race violation_raw violation search_conducted  \
# ...

# %% [markdown]
# # for numeric

# %%
data.describe(include=[np.number])
# for all numeric column
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %% [markdown]
# # for categorical

# %%
data.describe(include='O')
# Out:
#         stop_date stop_time driver_gender driver_race violation_raw violation  \
# count       65535     65535         61474       61475         61475     61475
# unique       2651      1432             2           5            12         6
# top     1/11/2012     10:00             M       White      Speeding  Speeding
# freq           69       280         45164       45747         37204     37204
#
#                search_type stop_outcome is_arrested stop_duration
# count                 2479        61475       61475         61475
# unique                  23            6           2             4
# top     Incident to Arrest     Citation       False      0-15 Min
# freq                  1074        56564       59215         47379

# %% [markdown]
# # for categorical columns

# %%
data.describe(exclude=np.number)
# Out:
#         stop_date stop_time driver_gender driver_race violation_raw violation  \
# count       65535     65535         61474       61475         61475     61475
# unique       2651      1432             2           5            12         6
# top     1/11/2012     10:00             M       White      Speeding  Speeding
# freq           69       280         45164       45747         37204     37204
#
#        search_conducted         search_type stop_outcome is_arrested  \
# count             65535                2479        61475       61475
# unique                2                  23            6           2
# top               False  Incident to Arrest     Citation       False
# freq              63056                1074        56564       59215
#
#        stop_duration drugs_related_stop
# count          61475              65535
# unique             4                  2
# top         0-15 Min              False
# freq           47379              65017

# %% [markdown]
# # for all float64 and datetime type column

# %%
data.describe(datetime_is_numeric=True)
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %%
data.describe(include=data['driver_age'])
# you can assign your columns name 
# but i made something this sytex is not work

# %%
data.describe().head()
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000

# %% [markdown]
# # perform specific function of a specific columns by using agg()

# %%
# this functional specialization of the describe func.
data.agg({'country_name':['min','mean','count']})
# Out:
#        country_name
# min             NaN
# mean            NaN
# count           0.0

# %% [markdown]
# ## all perform with the help of agg()

# %%
data.agg({'driver_age_raw':['mean','median','count','max','min','count','sum','var',]})
# Out:
#         driver_age_raw
# mean      1.967791e+03
# median    1.978000e+03
# count     6.148100e+04
# max       8.801000e+03
# min       0.000000e+00
# count     6.148100e+04
# sum       1.209818e+08
# var       1.465313e+04

# %%
data.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# # column wise describe()

# %%
data['driver_age_raw'].describe()
# Out:
# count    61481.000000
# mean      1967.791106
# std        121.050106
# min          0.000000
# 25%       1965.000000
# 50%       1978.000000
# 75%       1985.000000
# max       8801.000000
# Name: driver_age_raw, dtype: float64

# %% [markdown]
# # if you want to describe more than one columns then you shoud remeber that you have to specify your columns in dataframe

# %%
data[['driver_age_raw','driver_age']].describe()
# Out:
#        driver_age_raw    driver_age
# count    61481.000000  61228.000000
# mean      1967.791106     34.148984
# std        121.050106     12.760710
# min          0.000000     15.000000
# 25%       1965.000000     23.000000
# 50%       1978.000000     31.000000
# 75%       1985.000000     43.000000
# max       8801.000000     88.000000
