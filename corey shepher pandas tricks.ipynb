# %% [markdown]
# ### pandas tricks and trips in one file

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.arange(1,101).reshape(25,4))

# %%
df[1:4]
# Out:
#     0   1   2   3
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df.loc[0:5,0:3]
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16
# 4  17  18  19  20
# 5  21  22  23  24

# %%
df.iloc[0:2,0:2]
# Out:
#    0  1
# 0  1  2
# 1  5  6

# %%
df[[1,2]] #for two column fatch
# Out:
#      1   2
# 0    2   3
# 1    6   7
# 2   10  11
# 3   14  15
# 4   18  19
# 5   22  23
# 6   26  27
# 7   30  31
# 8   34  35
# 9   38  39
# 10  42  43
# 11  46  47
# 12  50  51
# 13  54  55
# 14  58  59
# 15  62  63
# 16  66  67
# 17  70  71
# 18  74  75
# 19  78  79
# 20  82  83
# 21  86  87
# 22  90  91
# 23  94  95
# 24  98  99
